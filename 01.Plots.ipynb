# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
#load the libraries:
import numpy as np
# import matplotlib.pylab as plt
from matplotlib import animation, rc
# from IPython.display import HTML
# from mpl_toolkits.mplot3d import axes3d

# #Line needed to perform the animations
# rc('animation', html='html5');

# %%
# %matplotlib notebook
# %matplotlib notebook

# %%
# x coordinate
x = np.linspace(0, 2*np.pi, 100)

#Define plot, labels, and axes limits
fig, ax = plt.subplots()
ax.set_xlabel('X')
ax.set_ylabel('$D(x,t)$')
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(-1.1, 1.1)

#Define the line properties
linea, = ax.plot([],[],'-',color = 'b', label = 'prueba')

#wave speed
v=0.01
#wave length
l=2*np.pi
#Wave number:
k=2*np.pi/l
#angular frequency:
w=v*k

# Define the function of time
def graficar(t):
    y = np.sin(k*x-w*t)
    linea.set_data((x,y))
    return (linea, )

#Make the animation
anim = animation.FuncAnimation(fig, graficar, frames=300, interval=10, repeat=False)
anim
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
